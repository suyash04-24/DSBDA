# %% [markdown]
# ### ASSIGNMENT - 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(dataset['fare'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4720\1694218074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.distplot(dataset['fare'], kde=False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4720\1623915515.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'], kde=False)
# <Axes: xlabel='fare'>

# %%
#You can also pass the value for the bins parameter in order to see more or less details in the graph.
sns.jointplot(x='age', y='fare', data=dataset)

# %%
sns.distplot(dataset['fare'], kde=False, bins=10)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4720\1857470142.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'], kde=False, bins=10)
# <Axes: xlabel='fare'>

# %%
sns.jointplot(x='age', y='fare', data=dataset, kind='hex')

# %%
#The Pair Plot The paitplot() is a type of distribution plot that basically plots a joint plot for all the possible combination
dataset = dataset.dropna()
sns.pairplot(dataset, hue='sex')

# %%
#The rugplot() is used to draw small bars along x-axis for each point in the dataset
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>
